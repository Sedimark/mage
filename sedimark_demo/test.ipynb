# %%
import connector
import secret
import copy
import requests

# %%
bucket = {'host': 'https://stellio-dev.eglobalmark.com',
          'url_keycloak': 'https://sso.eglobalmark.com/auth/realms/stellio-dev/protocol/openid-connect/token',
          'client_id': secret.client_id,
          'client_secret': secret.client_secret,
          'entity_id': 'urn:ngsi-ld:WeatherObserved:EGM-Farm-Demo',
          'link_context': 'https://raw.githubusercontent.com/easy-global-market/ngsild-api-data-models/ec6bcc2ce73f29a8398188b75136c5a7f720cd6a/precipitation/jsonld-contexts/precipitationCompouned.jsonld',
          'time_query': 'timerel=after&timeAt=2023-08-01T00:00:00Z'}

# %%
stellio_dev = connector.DataStore_NGSILD(bucket['host'], bucket['url_keycloak'])
stellio_dev.getToken(bucket['client_id'], bucket['client_secret'])

# %%
load_data = connector.LoadData_NGSILD(stellio_dev, bucket['entity_id'], bucket['link_context'])
load_data.run(bucket)

# %%
bucket['contextual_data']
# Out:
# {'name': {'type': 'Property', 'value': 'EGM-Farm-Demo'},
#  'windDirection': {'type': 'Property',
#   'datasetId': 'urn:ngsi-ld:Dataset:windDirection:DEG:EdgeWeatherStation',
#   'value': 191,
#   'observedAt': '2023-08-30T16:53:42Z',
#   'unitCode': 'deg'},
#  'refCity': {'type': 'Relationship', 'object': 'urn:ngsi-ld:City:Valbonne'},
#  'illuminance': {'type': 'Property',
#   'datasetId': 'urn:ngsi-ld:Dataset:illuminance:LUX:EdgeWeatherStation',
#   'value': 204.24,
#   'observedAt': '2023-08-30T16:43:34Z',
#   'unitCode': 'LUX'},
#  'precipitation': {'type': 'Property',
#   'datasetId': 'urn:ngsi-ld:Dataset:precipitation:MM:EdgeWeatherStation',
#   'period': {'type': 'Property', 'value': 10, 'unitCode': 'MIN'},
#   'value': 208.04,
#   'observedAt': '2023-08-30T16:53:42Z',
#   'unitCode': 'G51'},
#  'temperature': {'type': 'Property',
#   'datasetId': 'urn:ngsi-ld:Dataset:temperature:CEL:EdgeWeatherStation',
#   'value': 23,
#   'observedAt': '2023-08-30T16:53:42Z',
#   'unitCode': 'CEL'},
#  'windSpeed': [{'type': 'Property',
#    'datasetId': 'urn:ngsi-ld:Dataset:gust:KMH:EdgeWeatherStation',
#    'value': 1.12,
#    'observedAt': '2023-08-30T16:43:34Z',
#    'unitCode': 'MTS'},
#   {'type': 'Property',
#    'datasetId': 'urn:ngsi-ld:Dataset:wind:KMH:AVG:EdgeWeatherStation',
#    'value': 0,
#    'observedAt': '2023-08-30T16:53:42Z',
#    'unitCode': 'MTS'}],
#  'category': {'type': 'Property', 'value': 'EGM-WeatherStation'},
#  'irradiance': {'type': 'Property',
#   'datasetId': 'urn:ngsi-ld:Dataset:irradiance:MBR:EdgeWeatherStation',
#   'value': 4570,
#   'observedAt': '2023-08-30T16:43:34Z',
#   'unitCode': 'D54'},
#  'location': {'type': 'GeoProperty',
#   'value': {'type': 'Point', 'coordinates': [7.038174, 43.6197969]}},
#  'humidity': {'type': 'Property',
#   'datasetId': 'urn:ngsi-ld:Dataset:humidity:P1:EdgeWeatherStation',
#   'value': 77,
#   'observedAt': '2023-08-30T16:43:34Z',
#   'unitCode': 'P1'}}

# %%
bucket['temporal_data']
# Out:
#                       humidity  illuminance  irradiance  precipitation  \
# observedAt
# 2023-08-01T00:06:19Z      94.0         0.00        20.0         186.14
# 2023-08-01T00:16:27Z      91.0         0.00         0.0         186.14
# 2023-08-01T00:26:35Z      92.0         0.00         0.0         186.14
# 2023-08-01T00:36:43Z      91.0         0.00         0.0         186.14
# 2023-08-01T00:46:51Z      89.0         0.00        10.0         186.14
# ...                        ...          ...         ...            ...
# 2023-08-30T16:13:10Z      75.0       398.80      5890.0         208.04
# 2023-08-30T16:23:18Z      66.0       477.52      5430.0         208.04
# 2023-08-30T16:33:26Z      64.0       446.88      5000.0         208.04
# 2023-08-30T16:43:34Z      67.0       204.24      4570.0         208.04
# 2023-08-30T16:53:42Z      67.0       519.96      4060.0         208.04
#
#                       temperature  windDirection  \
# observedAt
# 2023-08-01T00:06:19Z         20.0          223.0
# 2023-08-01T00:16:27Z         20.0          223.0
# 2023-08-01T00:26:35Z         20.0          223.0
# 2023-08-01T00:36:43Z         20.0          223.0
# 2023-08-01T00:46:51Z         21.0          224.0
# ...                           ...            ...
# 2023-08-30T16:13:10Z         24.0          184.0
# 2023-08-30T16:23:18Z         24.0          184.0
# 2023-08-30T16:33:26Z         24.0          207.0
# 2023-08-30T16:43:34Z         23.0          159.0
# 2023-08-30T16:53:42Z         23.0          191.0
#
#                       windSpeed urn:ngsi-ld:Dataset:gust:KMH:EdgeWeatherStation  \
# observedAt
# 2023-08-01T00:06:19Z                                               0.00
# 2023-08-01T00:16:27Z                                               0.00
# 2023-08-01T00:26:35Z                                               0.00
# 2023-08-01T00:36:43Z                                               0.00
# 2023-08-01T00:46:51Z                                               0.00
# ...                                                                 ...
# 2023-08-30T16:13:10Z                                               0.00
# 2023-08-30T16:23:18Z                                               1.12
# 2023-08-30T16:33:26Z                                               0.00
# 2023-08-30T16:43:34Z                                               1.12
# 2023-08-30T16:53:42Z                                               1.12
#
#                       windSpeed urn:ngsi-ld:Dataset:wind:KMH:AVG:EdgeWeatherStation
# observedAt
# 2023-08-01T00:06:19Z                                                0.0
# 2023-08-01T00:16:27Z                                                0.0
# 2023-08-01T00:26:35Z                                                0.0
# 2023-08-01T00:36:43Z                                                0.0
# 2023-08-01T00:46:51Z                                                0.0
# ...                                                                 ...
# 2023-08-30T16:13:10Z                                                0.0
# 2023-08-30T16:23:18Z                                                0.0
# 2023-08-30T16:33:26Z                                                0.0
# 2023-08-30T16:43:34Z                                                0.0
# 2023-08-30T16:53:42Z                                                0.0
#
# [3687 rows x 8 columns]

# %%
bucket['processed_contextual_data'] = copy.deepcopy(bucket['contextual_data'])
bucket['processed_contextual_data']['name']['value'] = 'EGM-Farm-Demo-test'
bucket['processed_contextual_data']['precipitation']['period']['value'] = 5
new_attrs = {
    'new_attrs': {
        'type': 'Property',
        'value': 'test'
    }
}
bucket['processed_contextual_data'].update(new_attrs)

bucket['processed_temporal_data'] = bucket['temporal_data'].copy()
bucket['processed_temporal_data']['humidity'] = bucket['processed_temporal_data']['humidity'] + 10
bucket['processed_temporal_data']['new_attrs_2'] = bucket['processed_temporal_data']['illuminance']

# %%
bucket['processed_contextual_data']
# Out:
# {'name': {'type': 'Property', 'value': 'EGM-Farm-Demo-test'},
#  'windDirection': {'type': 'Property',
#   'datasetId': 'urn:ngsi-ld:Dataset:windDirection:DEG:EdgeWeatherStation',
#   'value': 191,
#   'observedAt': '2023-08-30T16:53:42Z',
#   'unitCode': 'deg'},
#  'refCity': {'type': 'Relationship', 'object': 'urn:ngsi-ld:City:Valbonne'},
#  'illuminance': {'type': 'Property',
#   'datasetId': 'urn:ngsi-ld:Dataset:illuminance:LUX:EdgeWeatherStation',
#   'value': 204.24,
#   'observedAt': '2023-08-30T16:43:34Z',
#   'unitCode': 'LUX'},
#  'precipitation': {'type': 'Property',
#   'datasetId': 'urn:ngsi-ld:Dataset:precipitation:MM:EdgeWeatherStation',
#   'period': {'type': 'Property', 'value': 5, 'unitCode': 'MIN'},
#   'value': 208.04,
#   'observedAt': '2023-08-30T16:53:42Z',
#   'unitCode': 'G51'},
#  'temperature': {'type': 'Property',
#   'datasetId': 'urn:ngsi-ld:Dataset:temperature:CEL:EdgeWeatherStation',
#   'value': 23,
#   'observedAt': '2023-08-30T16:53:42Z',
#   'unitCode': 'CEL'},
#  'windSpeed': [{'type': 'Property',
#    'datasetId': 'urn:ngsi-ld:Dataset:gust:KMH:EdgeWeatherStation',
#    'value': 1.12,
#    'observedAt': '2023-08-30T16:43:34Z',
#    'unitCode': 'MTS'},
#   {'type': 'Property',
#    'datasetId': 'urn:ngsi-ld:Dataset:wind:KMH:AVG:EdgeWeatherStation',
#    'value': 0,
#    'observedAt': '2023-08-30T16:53:42Z',
#    'unitCode': 'MTS'}],
#  'category': {'type': 'Property', 'value': 'EGM-WeatherStation'},
#  'irradiance': {'type': 'Property',
#   'datasetId': 'urn:ngsi-ld:Dataset:irradiance:MBR:EdgeWeatherStation',
#   'value': 4570,
#   'observedAt': '2023-08-30T16:43:34Z',
#   'unitCode': 'D54'},
#  'location': {'type': 'GeoProperty',
#   'value': {'type': 'Point', 'coordinates': [7.038174, 43.6197969]}},
#  'humidity': {'type': 'Property',
#   'datasetId': 'urn:ngsi-ld:Dataset:humidity:P1:EdgeWeatherStation',
#   'value': 77,
#   'observedAt': '2023-08-30T16:43:34Z',
#   'unitCode': 'P1'},
#  'new_attrs': {'type': 'Property', 'value': 'test'}}

# %%
bucket['processed_temporal_data']
# Out:
#                       humidity  illuminance  irradiance  precipitation  \
# observedAt
# 2023-08-01T00:06:19Z     104.0         0.00        20.0         186.14
# 2023-08-01T00:16:27Z     101.0         0.00         0.0         186.14
# 2023-08-01T00:26:35Z     102.0         0.00         0.0         186.14
# 2023-08-01T00:36:43Z     101.0         0.00         0.0         186.14
# 2023-08-01T00:46:51Z      99.0         0.00        10.0         186.14
# ...                        ...          ...         ...            ...
# 2023-08-30T16:13:10Z      85.0       398.80      5890.0         208.04
# 2023-08-30T16:23:18Z      76.0       477.52      5430.0         208.04
# 2023-08-30T16:33:26Z      74.0       446.88      5000.0         208.04
# 2023-08-30T16:43:34Z      77.0       204.24      4570.0         208.04
# 2023-08-30T16:53:42Z      77.0       519.96      4060.0         208.04
#
#                       temperature  windDirection  \
# observedAt
# 2023-08-01T00:06:19Z         20.0          223.0
# 2023-08-01T00:16:27Z         20.0          223.0
# 2023-08-01T00:26:35Z         20.0          223.0
# 2023-08-01T00:36:43Z         20.0          223.0
# 2023-08-01T00:46:51Z         21.0          224.0
# ...                           ...            ...
# 2023-08-30T16:13:10Z         24.0          184.0
# 2023-08-30T16:23:18Z         24.0          184.0
# 2023-08-30T16:33:26Z         24.0          207.0
# 2023-08-30T16:43:34Z         23.0          159.0
# 2023-08-30T16:53:42Z         23.0          191.0
#
#                       windSpeed urn:ngsi-ld:Dataset:gust:KMH:EdgeWeatherStation  \
# observedAt
# 2023-08-01T00:06:19Z                                               0.00
# 2023-08-01T00:16:27Z                                               0.00
# 2023-08-01T00:26:35Z                                               0.00
# 2023-08-01T00:36:43Z                                               0.00
# 2023-08-01T00:46:51Z                                               0.00
# ...                                                                 ...
# 2023-08-30T16:13:10Z                                               0.00
# 2023-08-30T16:23:18Z                                               1.12
# 2023-08-30T16:33:26Z                                               0.00
# 2023-08-30T16:43:34Z                                               1.12
# 2023-08-30T16:53:42Z                                               1.12
#
#                       windSpeed urn:ngsi-ld:Dataset:wind:KMH:AVG:EdgeWeatherStation  \
# observedAt
# 2023-08-01T00:06:19Z                                                0.0
# 2023-08-01T00:16:27Z                                                0.0
# 2023-08-01T00:26:35Z                                                0.0
# 2023-08-01T00:36:43Z                                                0.0
# 2023-08-01T00:46:51Z                                                0.0
# ...                                                                 ...
# 2023-08-30T16:13:10Z                                                0.0
# 2023-08-30T16:23:18Z                                                0.0
# 2023-08-30T16:33:26Z                                                0.0
# 2023-08-30T16:43:34Z                                                0.0
# 2023-08-30T16:53:42Z                                                0.0
#
#                       new_attrs_2
# observedAt
# 2023-08-01T00:06:19Z         0.00
# 2023-08-01T00:16:27Z         0.00
# 2023-08-01T00:26:35Z         0.00
# 2023-08-01T00:36:43Z         0.00
# 2023-08-01T00:46:51Z         0.00
# ...                           ...
# 2023-08-30T16:13:10Z       398.80
# 2023-08-30T16:23:18Z       477.52
# 2023-08-30T16:33:26Z       446.88
# 2023-08-30T16:43:34Z       204.24
# 2023-08-30T16:53:42Z       519.96
#
# [3687 rows x 9 columns]

# %%
print('Test changes')
save_data = connector.SaveData_NGSILD(stellio_dev, bucket['entity_id'], bucket['link_context'])
save_data.run(bucket)
# Out:
# Test changes
# Contextual data update: 1/1 - status: 204
# Temporal data update: 1/1 - status: 204

# %%
load_data = connector.LoadData_NGSILD(stellio_dev, bucket['entity_id'], bucket['link_context'])
load_data.run(bucket)

bucket['processed_contextual_data'] = copy.deepcopy(bucket['contextual_data'])
bucket['processed_contextual_data']['name']['value'] = 'EGM-Farm-Demo'
bucket['processed_contextual_data']['precipitation']['period']['value'] = 10

bucket['processed_temporal_data'] = bucket['temporal_data'].copy()
bucket['processed_temporal_data']['humidity'] = bucket['processed_temporal_data']['humidity'] - 10

print('Revert test changes')
save_data = connector.SaveData_NGSILD(stellio_dev, bucket['entity_id'], bucket['link_context'])
save_data.run(bucket)
# Out:
# Revert test changes
# Contextual data update: 1/1 - status: 204
# Temporal data update: 1/1 - status: 204

# %%
r = requests.delete(f'{stellio_dev.host}/ngsi-ld/v1/entities/{bucket["entity_id"]}/attrs/new_attrs', headers=load_data.headers)
print(r.status_code)
# Out:
# 204

# %%
r = requests.delete(f'{stellio_dev.host}/ngsi-ld/v1/entities/{bucket["entity_id"]}/attrs/new_attrs_2', headers=load_data.headers)
print(r.status_code)
# Out:
# 204

# %%
load_data = connector.LoadData_NGSILD(stellio_dev, bucket['entity_id'], bucket['link_context'])
load_data.run(bucket)

bucket['processed_contextual_data'] = copy.deepcopy(bucket['contextual_data'])
bucket['processed_temporal_data'] = bucket['temporal_data'].copy()

print('No changes')
save_data = connector.SaveData_NGSILD(stellio_dev, bucket['entity_id'], bucket['link_context'])
save_data.run(bucket)
# Out:
# No changes
# No new or modified contextual data to update
# No new or modified temporal data to update
